# %%
import pandas as pd

# %%
d=pd.read_csv("games.csv.zip")
d
# Out:
#         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...

# %%
d.columns
# Out:
# Index(['app_id', 'title', 'date_release', 'win', 'mac', 'linux', 'rating',
#        'positive_ratio', 'user_reviews', 'price_final', 'price_original',
#        'discount', 'steam_deck'],
#       dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50872 entries, 0 to 50871
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app_id          50872 non-null  int64
#  1   title           50872 non-null  object
#  2   date_release    50872 non-null  object
#  3   win             50872 non-null  bool
#  4   mac             50872 non-null  bool
#  5   linux           50872 non-null  bool
#  6   rating          50872 non-null  object
#  7   positive_ratio  50872 non-null  int64
#  8   user_reviews    50872 non-null  int64
#  9   price_final     50872 non-null  float64
#  10  price_original  50872 non-null  float64
#  11  discount        50872 non-null  float64
#  12  steam_deck      50872 non-null  bool
# dtypes: bool(4), float64(3), int64(3), object(3)
# memory usage: 3.7+ MB

# %%
#feature engineering
x=d[['app_id','positive_ratio', 'price_final', 'price_original']]
x
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50872 entries, 0 to 50871
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app_id          50872 non-null  int64
#  1   positive_ratio  50872 non-null  int64
#  2   price_final     50872 non-null  float64
#  3   price_original  50872 non-null  float64
# dtypes: float64(2), int64(2)
# memory usage: 1.6 MB

# %%
y=d[['user_reviews']]
y
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50872 entries, 0 to 50871
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_reviews  50872 non-null  int64
# dtypes: int64(1)
# memory usage: 397.6 KB

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
ss
# Out:
# StandardScaler()

# %%
x=ss.fit_transform(x)
x
y=ss.fit(y)
y
# Out:
# StandardScaler()

# %%
pip install scikit_learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
x=d[['app_id','positive_ratio', 'price_final', 'price_original']]
y=d["user_reviews"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model=KNeighborsRegressor(n_neighbors=6,metric="euclidean")
model.fit(x,y)
# Out:
# KNeighborsRegressor(metric='euclidean', n_neighbors=6)

# %%
model = KNeighborsRegressor(n_neighbors=5)
model.fit(x_train, y_train)

print("Score:", model.score(x_test, y_test))
# Out:
# Score: 0.13650812051966854

# %%
x=['app_id','positive_ratio', 'price_final', 'price_original']
y=["user_reviews"]
def rec(user_reviews):
    x_index=d[d["user_reviews"]==user_reviews].index[0]
    query_point=d.loc[[x_index],x].values
    distance,indices=model.kneighbors(query_point)
    return d.iloc[indices[0]]["user_reviews"]
#3.test it
print(rec(2199))
# Out:
# 215      2542
# 27842      56
# 10491     150
# 7704      276
# 148      1352
# Name: user_reviews, dtype: int64
# C:\Users\GANESHMOORTHI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
