# %%
#?
import numpy as np
b=np.random.binomial(n=10,p=0.2,size=100)
b
# Out:
# array([0, 2, 0, 3, 0, 3, 1, 4, 1, 3, 0, 3, 2, 2, 4, 2, 2, 0, 2, 2, 3, 1,
#        2, 4, 2, 3, 4, 3, 2, 3, 1, 3, 1, 0, 4, 1, 3, 1, 0, 2, 1, 1, 3, 5,
#        2, 1, 2, 1, 0, 1, 2, 2, 1, 3, 3, 1, 0, 0, 4, 1, 0, 3, 1, 2, 2, 1,
#        3, 2, 0, 2, 3, 3, 1, 3, 2, 2, 2, 1, 2, 1, 1, 1, 0, 2, 2, 1, 1, 1,
#        4, 1, 3, 2, 3, 3, 3, 3, 2, 0, 1, 2], dtype=int32)

# %%
import statsmodels.api  as sm

# %%
sm.qqplot(b,line='45')
import matplotlib.pyplot as plt
plt.show()

# %%
n=np.random.normal(0,1,100)
sm.qqplot(n,line='45')
plt.show()

# %%
import pandas as pd
t=pd.read_csv("Titanic_dataset (2).csv")
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sm.qqplot(t['Age'],line='45')
plt.show()

# %%
#pandas
t.to_csv(r"C:\Users\GANESHMOORTHI\OneDrive\Desktop\pyTitanic_dataset (2).csv")
