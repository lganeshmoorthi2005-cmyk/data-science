# %%
import regex as rx

# %%
text="my ph no 9189189189"
n=rx.findall(r"\d",text)
print(n)
# Out:
# ['9', '1', '8', '9', '1', '8', '9', '1', '8', '9']

# %%
t="like machine learning"
m=rx.search("machine learning",t)
print(m)
print(m.group)
# Out:
# <regex.Match object; span=(5, 21), match='machine learning'>
# <built-in method group of _regex.Match object at 0x00000202F2AACB70>

# %%
t="like machine learning"
match=rx.match("machine learning",t)
# Out:
# None

# %%
text="  i like travel ?!#$^%"
d=rx.sub(r"[?!#$^%]","",text)
print(d)
# Out:
#   i like travel
